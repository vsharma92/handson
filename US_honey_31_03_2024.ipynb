# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/US_honey_dataset (5).csv")

# %%
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       state  colonies_number  yield_per_colony  production  \
# 0           0     Alabama            16000                58      928000
# 1           1     Arizona            52000                79     4108000
# 2           2    Arkansas            50000                60     3000000
# 3           3  California           420000                93    39060000
# 4           4    Colorado            45000                60     2700000
#
#     stocks  average_price  value_of_production  year
# 0    28000           62.0               575000  1995
# 1   986000           68.0              2793000  1995
# 2   900000           64.0              1920000  1995
# 3  4687000           60.0             23436000  1995
# 4  1404000           68.0              1836000  1995

# %%
df.tail()
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
#        stocks  average_price  value_of_production  year
# 1110    79000           8.23              1975000  2021
# 1111  1206000           2.52              7741000  2021
# 1112   136000           4.80              1238000  2021
# 1113   750000           2.81              5547000  2021
# 1114   242000           2.07              4562000  2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1115 non-null   int64
#  1   state                1115 non-null   object
#  2   colonies_number      1115 non-null   int64
#  3   yield_per_colony     1115 non-null   int64
#  4   production           1115 non-null   int64
#  5   stocks               1115 non-null   int64
#  6   average_price        1115 non-null   float64
#  7   value_of_production  1115 non-null   int64
#  8   year                 1115 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 78.5+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  colonies_number  yield_per_colony    production  \
# count  1115.00000      1115.000000       1115.000000  1.115000e+03
# mean    557.00000     62438.565022         59.743498  2.851268e+06
# std     322.01708     92648.175955         19.940500  5.561202e+06
# min       0.00000      2000.000000         19.000000  1.200000e+04
# 25%     278.50000      9000.000000         45.000000  2.460000e+05
# 50%     557.00000     26000.000000         57.000000  8.280000e+05
# 75%     835.50000     69000.000000         71.000000  2.700000e+06
# max    1114.00000    550000.000000        155.000000  3.906000e+07
#
#              stocks  average_price  value_of_production         year
# count  1.115000e+03    1115.000000         1.115000e+03  1115.000000
# mean   1.172625e+06     140.623076         5.667412e+06  2007.740807
# std    2.049556e+06     107.011544         9.459460e+06     7.823002
# min    9.000000e+03       1.300000         1.060000e+05  1995.000000
# ...

# %%
df.describe(include="all")
# Out:
#         Unnamed: 0    state  colonies_number  yield_per_colony    production  \
# count   1115.00000     1115      1115.000000       1115.000000  1.115000e+03
# unique         NaN       44              NaN               NaN           NaN
# top            NaN  Alabama              NaN               NaN           NaN
# freq           NaN       27              NaN               NaN           NaN
# mean     557.00000      NaN     62438.565022         59.743498  2.851268e+06
# std      322.01708      NaN     92648.175955         19.940500  5.561202e+06
# min        0.00000      NaN      2000.000000         19.000000  1.200000e+04
# 25%      278.50000      NaN      9000.000000         45.000000  2.460000e+05
# 50%      557.00000      NaN     26000.000000         57.000000  8.280000e+05
# 75%      835.50000      NaN     69000.000000         71.000000  2.700000e+06
# max     1114.00000      NaN    550000.000000        155.000000  3.906000e+07
#
# ...

# %%
df["state"].value_counts()
# Out:
# Alabama          27
# Missouri         27
# Arizona          27
# NewJersey        27
# NewYork          27
# NorthCarolina    27
# NorthDakota      27
# Ohio             27
# Oregon           27
# Pennsylvania     27
# SouthDakota      27
# Tennessee        27
# Texas            27
# Utah             27
# Vermont          27
# Virginia         27
# Washington       27
# WestVirginia     27
# Wisconsin        27
# Montana          27
# Nebraska         27
# Mississippi      27
# Minnesota        27
# Arkansas         27
# California       27
# Colorado         27
# Florida          27
# Georgia          27
# Hawaii           27
# Idaho            27
# Illinois         27
# Indiana          27
# Iowa             27
# Kansas           27
# Louisiana        27
# Maine            27
# Michigan         27
# Wyoming          27
# Kentucky         26
# NewMexico        18
# Nevada           15
# SouthCarolina    12
# Oklahoma          9
# Maryland          9
# Name: state, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#removing unwanted column

df = df.drop(columns=["Unnamed: 0"])
# df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df.shape
# Out:
# (1115, 8)

# %%
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# ...

# %%
df["state"].unique()
# Out:
# array(['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'NewJersey', 'NewMexico', 'NewYork',
#        'NorthCarolina', 'NorthDakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'SouthCarolina', 'SouthDakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'WestVirginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df["state"].nunique()
# Out:
# 44

# %%
plt.figure(figsize=(15,10))

sns.barplot(x=df["production"],y=df["state"])
plt.xlabel("Total Honey Production")
plt.ylabel("Honey Producting states")
plt.show()

# %% [markdown]
# #**Top Honey Producing States**

# %%
df2 = df.sort_values("production",ascending=False)

# %%
df2
# Out:
#              state  colonies_number  yield_per_colony  production    stocks  \
# 3       California           420000                93    39060000   4687000
# 134     California           450000                83    37350000  12326000
# 581    NorthDakota           390000                90    35100000   8424000
# 622    NorthDakota           450000                77    34650000   7623000
# 458    NorthDakota           370000                91    33670000   8418000
# ..             ...              ...               ...         ...       ...
# 769       Kentucky             3000                41       17000     17000
# 984  SouthCarolina            16000                48       15000     15000
# 955        Alabama             6000                45       14000     14000
# 835        Alabama             7000                47       13000     13000
# 689       Kentucky             4000                39       12000     12000
#
#      average_price  value_of_production  year
# ...

# %%
plt.figure(figsize=(15,10))

sns.barplot(x=df2["production"],y=df2["state"])
plt.xlabel("Total Honey Production")
plt.ylabel("Honey Producting states")
plt.show()

# %% [markdown]
# From the above plot, we can conclude that **North Dakota** is the top Honey Producing state and **Kentucky** is the least honey producing state

# %% [markdown]
# **Change in mean Average price of Honey From 1995 to 2021**

# %%
df3 = df.groupby("year")["average_price"].mean().reset_index()

# %%
df3
# Out:
#     year  average_price
# 0   1995      74.840909
# 1   1996      99.568182
# 2   1997      91.325581
# 3   1998      83.720930
# 4   1999      80.325581
# 5   2000      79.023256
# 6   2001      88.465116
# 7   2002     133.204545
# 8   2003     151.068182
# 9   2004     132.350000
# 10  2005     116.341463
# 11  2006     134.341463
# 12  2007     140.170732
# 13  2008     160.878049
# 14  2009     176.195122
# 15  2010     192.900000
# 16  2011     216.725000
# 17  2012     236.700000
# 18  2013     260.717949
# 19  2014     282.025000
# 20  2015     292.625000
# 21  2016     291.925000
# 22  2017     302.775000
# 23  2018       3.083500
# 24  2019       2.925500
# 25  2020       3.050000
# 26  2021       3.334250

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = df3["year"],y=df3["average_price"])
plt.xlabel("Year(1995 - 2021)")
plt.ylabel("Average Price")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x = df3["year"],y=df3["average_price"])
plt.xlabel("Year(1995 - 2021)")
plt.ylabel("Average Price")
plt.show()

# %% [markdown]
# **Change in the mean average Price of Honey from the year 2000 to 2006**

# %%
df4 = df[(df["year"]>=2000) & (df["year"]<=2006)]

# %%
df4
# Out:
#             state  colonies_number  yield_per_colony  production    stocks  \
# 217       Alabama            16000                78     1248000    187000
# 218       Arizona            40000                59     2360000   1322000
# 219      Arkansas            55000                93     5115000   3529000
# 220    California           440000                70    30800000  11396000
# 221      Colorado            29000                60     1740000    957000
# ..            ...              ...               ...         ...       ...
# 508      Virginia             8000                42      336000    114000
# 509    Washington            49000                52     2548000   1605000
# 510  WestVirginia             5000                42      210000     57000
# 511     Wisconsin            64000                93     5952000   2500000
# 512       Wyoming            39000                85     3315000    497000
#
#      average_price  value_of_production  year
# ...

# %%
df5 = df4.groupby("year")["average_price"].mean().reset_index()
df5
# Out:
#    year  average_price
# 0  2000      79.023256
# 1  2001      88.465116
# 2  2002     133.204545
# 3  2003     151.068182
# 4  2004     132.350000
# 5  2005     116.341463
# 6  2006     134.341463

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = df5["year"],y=df5["average_price"])
plt.xlabel("Year(2000 - 2006)")
plt.ylabel("Average Price")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x = df5["year"],y=df5["average_price"])
plt.xlabel("Year(2000 - 2006)")
plt.ylabel("Average Price")
plt.show()

# %% [markdown]
# **Which was the year when production of Honey was the highest?**

# %%
df7 = df.groupby('year').sum().reset_index()
df7
# Out:
# <ipython-input-74-ec9f0f46a0fe>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df7 = df.groupby('year').sum().reset_index()
#     year  colonies_number  yield_per_colony  production    stocks  \
# 0   1995          2639000              2944   210272000  42130000
# 1   1996          2560000              3083   197995000  46924000
# 2   1997          2565000              2965   191176000  68854000
# 3   1998          2618000              3008   219321000  80474000
# 4   1999          2674000              2815   204585000  79107000
# 5   2000          2617000              2904   220320000  85888000
# 6   2001          2500000              2804   185403000  64577000
# 7   2002          2516000              2960   170732000  38859000
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = df7["year"],y=df7["production"])
plt.xlabel("Year(1995 - 2021)")
plt.ylabel("Total Production")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x = df7["year"],y=df7["production"])
plt.xlabel("Year(1995 - 2021)")
plt.ylabel("Total Production")
plt.show()

# %% [markdown]
# From the above plots we can conclude that the top honey production was maximum in year 2000 and minimum in year 2021

# %% [markdown]
# **Which was the year when total mean value of production of Honey was the highest ?**

# %%
df8 = df.groupby("year")["value_of_production"].mean().reset_index()
df8
# Out:
#     year  value_of_production
# 0   1995         3.121000e+06
# 1   1996         4.085773e+06
# 2   1997         3.386000e+06
# 3   1998         3.395302e+06
# 4   1999         2.888070e+06
# 5   2000         3.047023e+06
# 6   2001         2.936302e+06
# 7   2002         5.016977e+06
# 8   2003         5.791659e+06
# 9   2004         4.976100e+06
# 10  2005         3.795390e+06
# 11  2006         3.886902e+06
# 12  2007         3.801634e+06
# 13  2008         5.466171e+06
# 14  2009         5.063463e+06
# 15  2010         6.959250e+06
# 16  2011         6.467200e+06
# 17  2012         7.018125e+06
# 18  2013         8.079949e+06
# 19  2014         9.612075e+06
# 20  2015         8.062625e+06
# 21  2016         8.382125e+06
# 22  2017         8.154950e+06
# 23  2018         8.269150e+06
# 24  2019         7.585950e+06
# 25  2020         7.545775e+06
# 26  2021         7.860325e+06

# %%
df8.sort_values("value_of_production",ascending=False)
# Out:
#     year  value_of_production
# 19  2014         9.612075e+06
# 21  2016         8.382125e+06
# 23  2018         8.269150e+06
# 22  2017         8.154950e+06
# 18  2013         8.079949e+06
# 20  2015         8.062625e+06
# 26  2021         7.860325e+06
# 24  2019         7.585950e+06
# 25  2020         7.545775e+06
# 17  2012         7.018125e+06
# 15  2010         6.959250e+06
# 16  2011         6.467200e+06
# 8   2003         5.791659e+06
# 13  2008         5.466171e+06
# 14  2009         5.063463e+06
# 7   2002         5.016977e+06
# 9   2004         4.976100e+06
# 1   1996         4.085773e+06
# 11  2006         3.886902e+06
# 12  2007         3.801634e+06
# 10  2005         3.795390e+06
# 3   1998         3.395302e+06
# 2   1997         3.386000e+06
# 0   1995         3.121000e+06
# 5   2000         3.047023e+06
# 6   2001         2.936302e+06
# 4   1999         2.888070e+06

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x = df8["year"],y=df8["value_of_production"])
plt.xlabel("Year(1995 - 2021)")
plt.ylabel("Value_of_ Production(Dollors)")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = df8["year"],y=df8["value_of_production"])
plt.xlabel("Year(1995 - 2021)")
plt.ylabel("Value_of_ Production(Dollors)")
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.pie(df8["value_of_production"],labels=df8["year"],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# From the above plots we can conclude that 2014 is the year with the highest value of production and 1999 is the year with the minumum value of production

# %% [markdown]
# **States having the Highest no.of Colonies**

# %%
df9 = df.groupby("state")["colonies_number"].sum().reset_index()
df9
# Out:
#             state  colonies_number
# 0         Alabama           288000
# 1         Arizona           854000
# 2        Arkansas           908000
# 3      California         10135000
# 4        Colorado           799000
# 5         Florida          5528000
# 6         Georgia          1917000
# 7          Hawaii           296000
# 8           Idaho          2705000
# 9        Illinois           236000
# 10        Indiana           213000
# 11           Iowa           962000
# 12         Kansas           301000
# 13       Kentucky           113000
# 14      Louisiana          1066000
# 15          Maine           252000
# 16       Maryland            48000
# 17       Michigan          2168000
# 18      Minnesota          3498000
# 19    Mississippi           485000
# 20       Missouri           390000
# 21        Montana          3725000
# 22       Nebraska          1279000
# 23         Nevada           157000
# 24      NewJersey           299000
# 25      NewMexico           185000
# ...

# %%
df9 = df9.sort_values("colonies_number",ascending=False)

# %%
df9
# Out:
#             state  colonies_number
# 28    NorthDakota         10710000
# 3      California         10135000
# 34    SouthDakota          6639000
# 5         Florida          5528000
# 21        Montana          3725000
# 18      Minnesota          3498000
# 36          Texas          2876000
# 8           Idaho          2705000
# 17       Michigan          2168000
# 6         Georgia          1917000
# 40     Washington          1709000
# 42      Wisconsin          1698000
# 31         Oregon          1594000
# 26        NewYork          1588000
# 22       Nebraska          1279000
# 14      Louisiana          1066000
# 43        Wyoming          1065000
# 11           Iowa           962000
# 2        Arkansas           908000
# 1         Arizona           854000
# 4        Colorado           799000
# 37           Utah           719000
# 32   Pennsylvania           586000
# 19    Mississippi           485000
# 29           Ohio           449000
# 20       Missouri           390000
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = df9["state"],y=df9["colonies_number"])
plt.xlabel("States")
plt.ylabel("Colonies")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **State with Highest number of stocks:**
